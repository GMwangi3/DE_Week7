# %% [markdown]
# <a href="https://colab.research.google.com/github/GMwangi3/DE_Week7/blob/main/V1_Data_Pipelines_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Pipelines with Python

# %% [markdown]
# I am developing an automated data pipeline that can extract billing data from multiple sources and transform it into a structured format for efficient analysis and revenue reporting.

# %% [markdown]
# ## Pre-requisites

# %%
# Pre-requisite 1
# ---
# Importing pandas library for data manipulation
import pandas as pd
# Importing numpy library for scientific computations
import numpy as np

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### Load and Review the datasets

# %%
# Dataset url = https://bit.ly/416WE1X
# Dataset1 - subscriptions
subscription_df = pd.read_csv('https://raw.githubusercontent.com/GMwangi3/DE_Week7/main/dataset1.csv')
subscription_df.head(5)
# Out:
#    customer_id date_of_purchase  total_amount_billed payment_status  \
# 0          101       04/01/2021                  100           paid
# 1          102       04/02/2021                  200           paid
# 2          103       04/02/2021                   50        overdue
# 3          104       04/03/2021                   75       disputed
# 4          105       04/04/2021                  125           paid
#
#   payment_method promo_code country_of_purchase
# 0    credit card     PROMO1                 USA
# 1  bank transfer     PROMO2                 USA
# 2    credit card        NaN                  UK
# 3       e-wallet     PROMO3                  UK
# 4    credit card     PROMO4                 USA

# %%
# Dataset2 - Payments
payment_df = pd.read_csv('https://raw.githubusercontent.com/GMwangi3/DE_Week7/main/dataset1.csv')
payment_df.head(5)
# Out:
#    customer_id date_of_purchase  total_amount_billed payment_status  \
# 0          101       04/01/2021                  100           paid
# 1          102       04/02/2021                  200           paid
# 2          103       04/02/2021                   50        overdue
# 3          104       04/03/2021                   75       disputed
# 4          105       04/04/2021                  125           paid
#
#   payment_method promo_code country_of_purchase
# 0    credit card     PROMO1                 USA
# 1  bank transfer     PROMO2                 USA
# 2    credit card        NaN                  UK
# 3       e-wallet     PROMO3                  UK
# 4    credit card     PROMO4                 USA

# %%
# Dataset3 - Refunds
refund_df = pd.read_csv('https://raw.githubusercontent.com/GMwangi3/DE_Week7/main/dataset1.csv')
refund_df.head(5)
# Out:
#    customer_id date_of_purchase  total_amount_billed payment_status  \
# 0          101       04/01/2021                  100           paid
# 1          102       04/02/2021                  200           paid
# 2          103       04/02/2021                   50        overdue
# 3          104       04/03/2021                   75       disputed
# 4          105       04/04/2021                  125           paid
#
#   payment_method promo_code country_of_purchase
# 0    credit card     PROMO1                 USA
# 1  bank transfer     PROMO2                 USA
# 2    credit card        NaN                  UK
# 3       e-wallet     PROMO3                  UK
# 4    credit card     PROMO4                 USA

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### Get column data types

# %%
# Function that prints the data types of columns for a given dataframe
def get_datatypes(df):
  df_name =[x for x in globals() if globals()[x] is df][0]
  print("\n" + df_name)
  print("=================")
  print(df.dtypes)

df_list = [subscription_df, payment_df, refund_df]

for df in df_list:
  get_datatypes(df)
# Out:
# subscription_df
# =================
# customer_id             int64
# date_of_purchase       object
# total_amount_billed     int64
# payment_status         object
# payment_method         object
# promo_code             object
# country_of_purchase    object
# dtype: object
#
# payment_df
# =================
# customer_id             int64
# date_of_purchase       object
# total_amount_billed     int64
# payment_status         object
# payment_method         object
# promo_code             object
# country_of_purchase    object
# dtype: object
#
# refund_df
# =================
# customer_id             int64
# date_of_purchase       object
# total_amount_billed     int64
# payment_status         object
# payment_method         object
# promo_code             object
# country_of_purchase    object
# dtype: object

# %% [markdown]
# ### Missing Values

# %%
# Function that prints the sum of missing values per columns for a given dataframe
def get_nulls(df):
  df_name =[x for x in globals() if globals()[x] is df][0]
  print("\n" + df_name)
  print("=================\n")
  print(df.isna().sum())

for df in df_list:
  get_nulls(df)
# Out:
# subscription_df
# =================
#
# customer_id            0
# date_of_purchase       0
# total_amount_billed    0
# payment_status         0
# payment_method         0
# promo_code             3
# country_of_purchase    0
# dtype: int64
#
# payment_df
# =================
#
# customer_id            0
# date_of_purchase       0
# total_amount_billed    0
# payment_status         0
# payment_method         0
# promo_code             3
# country_of_purchase    0
# dtype: int64
#
# refund_df
# =================
#
# customer_id            0
# date_of_purchase       0
# total_amount_billed    0
# payment_status         0
# payment_method         0
# promo_code             3
# country_of_purchase    0
# dtype: int64

# %% [markdown]
# ### Duplicate data

# %%
# Function that prints number of duplicate records
def get_duplicates(df):
  df_name =[x for x in globals() if globals()[x] is df][0]
  print("\n" + df_name)
  print("=================\n")
  print(sum(df.duplicated()))

for df in df_list:
  get_duplicates(df)
# Out:
# subscription_df
# =================
#
# 0
#
# payment_df
# =================
#
# 0
#
# refund_df
# =================
#
# 0

# %% [markdown]
# There are missing values for the Promo_code

# %% [markdown]
# ## 3. Data Transformation

# %% [markdown]
# ### Date Formatting

# %%
# Convert the date/time columns
subscription_df['date_of_purchase'] = pd.to_datetime(subscription_df['date_of_purchase'], infer_datetime_format=True)
payment_df['date_of_payment'] = pd.to_datetime(payment_df['date_of_payment'], infer_datetime_format=True)
refund_df['date_of_refund'] = pd.to_datetime(refund_df['date_of_refund'], infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_of_payment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ddfc6840a271> in <cell line: 3>()
#       1 # Convert the date/time columns
#       2 subscription_df['date_of_purchase'] = pd.to_datetime(subscription_df['date_of_purchase'], infer_datetime_format=True)
# ----> 3 payment_df['date_of_payment'] = pd.to_datetime(payment_df['date_of_payment'], infer_datetime_format=True)
#       4 refund_df['date_of_refund'] = pd.to_datetime(refund_df['date_of_refund'], infer_datetime_format=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'date_of_payment'

# %% [markdown]
# ### Merging the Datasets

# %%
# Merge the datasets
subscription_payment_merge = pd.merge(left=subscription_df, right=payment_df, how='left', left_on=['customer_id','payment_status','payment_method'], right_on= ['customer_id','payment_status','payment_method'])
final_merged_df = pd.merge(left=subscription_payment_merge, right=refund_df, how='left', left_on=['customer_id'], right_on= ['customer_id'])

final_merged_df
# Out:
#     customer_id date_of_purchase_x  total_amount_billed_x payment_status_x  \
# 0           101         2021-04-01                    100             paid
# 1           102         2021-04-02                    200             paid
# 2           103         2021-04-02                     50          overdue
# 3           104         2021-04-03                     75         disputed
# 4           105         2021-04-04                    125             paid
# 5           106         2021-04-05                    150             paid
# 6           107         2021-04-06                     75          overdue
# 7           108         2021-04-06                    100          overdue
# 8           109         2021-04-07                     50             paid
# 9           110         2021-04-07                     25          overdue
# 10          111         2021-04-08                    175             paid
# 11          112         2021-04-08                    200             paid
# 12          113         2021-04-09                     50         disputed
# 13          114         2021-04-10                    100             paid
# 14          115         2021-04-10                     75          overdue
#
#    payment_method_x promo_code_x country_of_purchase_x date_of_purchase_y  \
# 0       credit card       PROMO1                   USA         04/01/2021
# 1     bank transfer       PROMO2                   USA         04/02/2021
# 2       credit card          NaN                    UK         04/02/2021
# 3          e-wallet       PROMO3                    UK         04/03/2021
# 4       credit card       PROMO4                   USA         04/04/2021
# 5       credit card          NaN                    UK         04/05/2021
# 6          e-wallet       PROMO5                   USA         04/06/2021
# 7     bank transfer       PROMO6                   USA         04/06/2021
# 8     bank transfer          NaN                    UK         04/07/2021
# 9       credit card       PROMO7                   USA         04/07/2021
# 10         e-wallet       PROMO8                    UK         04/08/2021
# 11    bank transfer       PROMO9                   USA         04/08/2021
# 12      credit card      PROMO10                   USA         04/09/2021
# 13      credit card      PROMO11                   USA         04/10/2021
# 14         e-wallet      PROMO12                    UK         04/10/2021
#
#     total_amount_billed_y promo_code_y country_of_purchase_y date_of_purchase  \
# 0                     100       PROMO1                   USA       04/01/2021
# 1                     200       PROMO2                   USA       04/02/2021
# 2                      50          NaN                    UK       04/02/2021
# 3                      75       PROMO3                    UK       04/03/2021
# 4                     125       PROMO4                   USA       04/04/2021
# 5                     150          NaN                    UK       04/05/2021
# 6                      75       PROMO5                   USA       04/06/2021
# 7                     100       PROMO6                   USA       04/06/2021
# 8                      50          NaN                    UK       04/07/2021
# 9                      25       PROMO7                   USA       04/07/2021
# 10                    175       PROMO8                    UK       04/08/2021
# 11                    200       PROMO9                   USA       04/08/2021
# 12                     50      PROMO10                   USA       04/09/2021
# 13                    100      PROMO11                   USA       04/10/2021
# 14                     75      PROMO12                    UK       04/10/2021
#
#     total_amount_billed payment_status_y payment_method_y promo_code  \
# 0                   100             paid      credit card     PROMO1
# 1                   200             paid    bank transfer     PROMO2
# 2                    50          overdue      credit card        NaN
# 3                    75         disputed         e-wallet     PROMO3
# 4                   125             paid      credit card     PROMO4
# 5                   150             paid      credit card        NaN
# 6                    75          overdue         e-wallet     PROMO5
# 7                   100          overdue    bank transfer     PROMO6
# 8                    50             paid    bank transfer        NaN
# 9                    25          overdue      credit card     PROMO7
# 10                  175             paid         e-wallet     PROMO8
# 11                  200             paid    bank transfer     PROMO9
# 12                   50         disputed      credit card    PROMO10
# 13                  100             paid      credit card    PROMO11
# 14                   75          overdue         e-wallet    PROMO12
#
#    country_of_purchase
# 0                  USA
# 1                  USA
# 2                   UK
# 3                   UK
# 4                  USA
# 5                   UK
# 6                  USA
# 7                  USA
# 8                   UK
# 9                  USA
# 10                  UK
# 11                 USA
# 12                 USA
# 13                 USA
# 14                  UK

# %% [markdown]
# ### Unpaid Bills

# %%
final_merged_df = final_merged_df[final_merged_df['payment_status'] != 'paid']
final_merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ce4b377236a4> in <cell line: 1>()
# ----> 1 final_merged_df = final_merged_df[final_merged_df['payment_status'] != 'paid']
#       2 final_merged_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'payment_status'

# %% [markdown]
# ## 4. Data Loading

# %% [markdown]
# ### Output to csv file

# %%
final_merged_df.to_csv('unpaid_bills.csv', header=True, index=False)

# %% [markdown]
# ## 5. Automation

# %% [markdown]
# I will configure a cronjob to run the notebook everydat at 4am:
#
# 0 4 * * * /path/to/notebook.ipynb
